# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('SampleSuperstore.csv', encoding='cp1251')
#df = pd.read_csv('SampleSuperstore.csv', encoding_errors='ignore') #also worked
df.head()
# Out:
#                                               Row ID        Order ID  \
# 0                                                  1  CA-2016-152156
# 1  2,CA-2016-152156,11/8/2016,11/11/2016,Second C...             NaN
# 2                                                  3  CA-2016-138688
# 3                                                  4  US-2015-108966
# 4                                                  5  US-2015-108966
#
#    Order Date   Ship Date       Ship Mode Customer ID    Customer Name  \
# 0   11/8/2016  11/11/2016    Second Class    CG-12520      Claire Gute
# 1         NaN         NaN             NaN         NaN              NaN
# 2   6/12/2016   6/16/2016    Second Class    DV-13045  Darrin Van Huff
# 3  10/11/2015  10/18/2015  Standard Class    SO-20335   Sean O'Donnell
# 4  10/11/2015  10/18/2015  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City  ... Postal Code  Region  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (7484, 21)

# %%
df
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2         3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3         4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4         5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 6         7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...     ...             ...         ...         ...             ...
# 9987   9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988   9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989   9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990   9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991   9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df
# Out:
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2016-152156 2016-11-08  11/11/2016    Second Class
# 2         3  CA-2016-138688 2016-06-12   6/16/2016    Second Class
# 3         4  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# 4         5  US-2015-108966 2015-10-11  10/18/2015  Standard Class
# 6         7  CA-2014-115812 2014-06-09   6/14/2014  Standard Class
# ...     ...             ...        ...         ...             ...
# 9987   9988  CA-2017-163629 2017-11-17  11/21/2017  Standard Class
# 9988   9989  CA-2017-163629 2017-11-17  11/21/2017  Standard Class
# 9989   9990  CA-2014-110422 2014-01-21   1/23/2014    Second Class
# 9990   9991  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
# 9991   9992  CA-2017-121258 2017-02-26    3/3/2017  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.sort_values('Customer ID').head(10)
# Out:
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 5198   5199  CA-2016-103982 2016-03-03    3/8/2016  Standard Class
# 5200   5201  CA-2016-103982 2016-03-03    3/8/2016  Standard Class
# 2229   2230  CA-2014-128055 2014-03-31    4/5/2014  Standard Class
# 2230   2231  CA-2014-128055 2014-03-31    4/5/2014  Standard Class
# 1160   1161  CA-2017-147039 2017-06-29    7/4/2017  Standard Class
# 7468   7469  CA-2014-138100 2014-09-15   9/20/2014  Standard Class
# 1172   1173  CA-2014-158064 2014-04-21   4/25/2014  Standard Class
# 807     808  CA-2015-140921 2015-02-03    2/5/2015     First Class
# 2263   2264  CA-2016-131065 2016-11-14  11/16/2016    Second Class
# 2264   2265  CA-2016-131065 2016-11-14  11/16/2016    Second Class
#
#      Customer ID Customer Name   Segment        Country           City  ...  \
# 5198    AA-10315    Alex Avila  Consumer  United States     Round Rock  ...
# ...

# %%
#Lat purchase for every id
df = df.loc[df.groupby('Customer ID')['Order Date'].idxmax()].sort_values('Customer ID')
df.head(10)
# Out:
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 1160   1161  CA-2017-147039 2017-06-29    7/4/2017  Standard Class
# 6747   6748  CA-2017-100230 2017-12-11  12/15/2017  Standard Class
# 12       13  CA-2017-114412 2017-04-15   4/20/2017  Standard Class
# 7489   7490  CA-2017-157196 2017-11-05   11/9/2017  Standard Class
# 8801   8802  CA-2016-140935 2016-11-10  11/12/2016     First Class
# 8168   8169  CA-2017-107174 2017-11-06  11/13/2017  Standard Class
# 2552   2553  CA-2017-101042 2017-11-19  11/23/2017  Standard Class
# 1597   1598  CA-2017-158876 2017-11-19  11/21/2017    Second Class
# 3433   3434  CA-2017-131212 2017-12-05   12/9/2017  Standard Class
# 4572   4573  CA-2017-126662 2017-07-17   7/21/2017  Standard Class
#
#      Customer ID         Customer Name      Segment        Country  \
# 1160    AA-10315            Alex Avila     Consumer  United States
# 6747    AA-10375          Allen Armold     Consumer  United States
# ...

# %%
df.shape
# Out:
# (791, 21)

# %%
df['City'].nunique()
# Out:
# 245

# %%
cities = []
len(df['City'].unique())
# Out:
# 245

# %%
df['City'].count()
# Out:
# 791

# %%
sorted(df['City'].unique())
# Out:
# ['Aberdeen',
#  'Abilene',
#  'Akron',
#  'Albuquerque',
#  'Alexandria',
#  'Anaheim',
#  'Apple Valley',
#  'Arlington',
#  'Asheville',
#  'Athens',
#  'Atlanta',
#  'Auburn',
#  'Aurora',
#  'Austin',
#  'Baltimore',
#  'Belleville',
#  'Bellevue',
#  'Bellingham',
#  'Bloomington',
#  'Bossier City',
#  'Bowling Green',
#  'Brentwood',
#  'Buffalo',
#  'Burlington',
#  'Camarillo',
#  'Cambridge',
#  'Canton',
#  'Carlsbad',
#  'Carrollton',
#  'Cedar Hill',
#  'Chandler',
#  'Charlotte',
#  'Charlottesville',
#  'Chattanooga',
#  'Chesapeake',
#  'Cheyenne',
#  'Chicago',
#  'Cincinnati',
#  'Cleveland',
#  'Clinton',
#  'Coachella',
#  'College Station',
#  'Colorado Springs',
#  'Columbia',
#  'Columbus',
#  'Concord',
#  'Coppell',
#  'Costa Mesa',
#  'Dallas',
#  'Danbury',
#  'Danville',
#  'Decatur',
#  'Deltona',
#  'Denver',
#  'Des Moines',
#  'Detroit',
#  'Dover',
#  'Dublin',
#  'Durham',
#  'Eagan',
#  'Edinburg',
#  'Edmonds',
#  'El Paso',
#  'Encinitas',
# ...

# %%
cities = []

# %%
#count value of unique cities
for city in sorted(df['City'].unique()):
    for i in city.split(', '):
        if i not in cities:
            cities.append(i)
            # print name of the city
            print(i)
            # print value of unique cities
            print(df['City'].str.contains(i).sum())
# Out:
# Aberdeen
# 1
# Abilene
# 1
# Akron
# 3
# Albuquerque
# 3
# Alexandria
# 1
# Anaheim
# 2
# Apple Valley
# 2
# Arlington
# 2
# Asheville
# 3
# Athens
# 1
# Atlanta
# 3
# Auburn
# 4
# Aurora
# 5
# Austin
# 7
# Baltimore
# 2
# Belleville
# 1
# Bellevue
# 1
# Bellingham
# 1
# Bloomington
# 1
# Bossier City
# 1
# Bowling Green
# 1
# Brentwood
# 2
# Buffalo
# 1
# Burlington
# 7
# Camarillo
# 1
# Cambridge
# 1
# Canton
# 2
# Carlsbad
# 1
# Carrollton
# 1
# Cedar Hill
# 1
# Chandler
# 3
# Charlotte
# 7
# Charlottesville
# 1
# Chattanooga
# 1
# Chesapeake
# 1
# Cheyenne
# 1
# Chicago
# 26
# Cincinnati
# 1
# Cleveland
# 5
# Clinton
# 1
# Coachella
# 1
# College Station
# 2
# Colorado Springs
# 1
# Columbia
# 2
# Columbus
# 18
# Concord
# 1
# Coppell
# 1
# Costa Mesa
# 2
# Dallas
# 14
# Danbury
# 1
# Danville
# 1
# Decatur
# 2
# Deltona
# 1
# Denver
# 2
# Des Moines
# 1
# Detroit
# 5
# Dover
# 1
# Dublin
# 3
# Durham
# 1
# Eagan
# 1
# Edinburg
# 1
# Edmonds
# 2
# El Paso
# 1
# Encinitas
# 1
# ...

# %%
cities
# Out:
# ['Aberdeen',
#  'Abilene',
#  'Akron',
#  'Albuquerque',
#  'Alexandria',
#  'Anaheim',
#  'Apple Valley',
#  'Arlington',
#  'Asheville',
#  'Athens',
#  'Atlanta',
#  'Auburn',
#  'Aurora',
#  'Austin',
#  'Baltimore',
#  'Belleville',
#  'Bellevue',
#  'Bellingham',
#  'Bloomington',
#  'Bossier City',
#  'Bowling Green',
#  'Brentwood',
#  'Buffalo',
#  'Burlington',
#  'Camarillo',
#  'Cambridge',
#  'Canton',
#  'Carlsbad',
#  'Carrollton',
#  'Cedar Hill',
#  'Chandler',
#  'Charlotte',
#  'Charlottesville',
#  'Chattanooga',
#  'Chesapeake',
#  'Cheyenne',
#  'Chicago',
#  'Cincinnati',
#  'Cleveland',
#  'Clinton',
#  'Coachella',
#  'College Station',
#  'Colorado Springs',
#  'Columbia',
#  'Columbus',
#  'Concord',
#  'Coppell',
#  'Costa Mesa',
#  'Dallas',
#  'Danbury',
#  'Danville',
#  'Decatur',
#  'Deltona',
#  'Denver',
#  'Des Moines',
#  'Detroit',
#  'Dover',
#  'Dublin',
#  'Durham',
#  'Eagan',
#  'Edinburg',
#  'Edmonds',
#  'El Paso',
#  'Encinitas',
# ...

# %%
df.head(10)
# Out:
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 1160   1161  CA-2017-147039 2017-06-29    7/4/2017  Standard Class
# 6747   6748  CA-2017-100230 2017-12-11  12/15/2017  Standard Class
# 12       13  CA-2017-114412 2017-04-15   4/20/2017  Standard Class
# 7489   7490  CA-2017-157196 2017-11-05   11/9/2017  Standard Class
# 8801   8802  CA-2016-140935 2016-11-10  11/12/2016     First Class
# 8168   8169  CA-2017-107174 2017-11-06  11/13/2017  Standard Class
# 2552   2553  CA-2017-101042 2017-11-19  11/23/2017  Standard Class
# 1597   1598  CA-2017-158876 2017-11-19  11/21/2017    Second Class
# 3433   3434  CA-2017-131212 2017-12-05   12/9/2017  Standard Class
# 4572   4573  CA-2017-126662 2017-07-17   7/21/2017  Standard Class
#
#      Customer ID         Customer Name      Segment        Country  \
# 1160    AA-10315            Alex Avila     Consumer  United States
# 6747    AA-10375          Allen Armold     Consumer  United States
# ...

# %%
#Plots
#1. Pie?
'''
import math
plt.gcf().set_size_inches(12, 12)
sns.set_style('darkgrid')

max_val = max(df['Sales'])*1.01
ax = plt.subplot(projection='polar')

ax.set_theta_zero_location('N')
ax.set_theta_direction(1)
ax.set_rlabel_position(0)
ax.set_thetagrids([], labels=[])
ax.set_rgrids(range(len(df)), labels= df['Sub-Category'])

'''
# Out:
# "\nimport math\nplt.gcf().set_size_inches(12, 12)\nsns.set_style('darkgrid')\n\n# Установка максимального значения\n\nmax_val = max(df['Sales'])*1.01\nax = plt.subplot(projection='polar')\n\n# Зададим внутренний график\n\nax.set_theta_zero_location('N')\nax.set_theta_direction(1)\nax.set_rlabel_position(0)\nax.set_thetagrids([], labels=[])\nax.set_rgrids(range(len(df)), labels= df['Sub-Category'])\n\n"

# %%
#Tree

import plotly.express as px
fig = px.treemap(df, path=[px.Constant('Sub-Category'), 'Sub-Category'],
              values=df['Sales'],
              color=df['Sales'],
                 color_continuous_scale='Spectral_r',
                 color_continuous_midpoint=np.average(df['Sales'])
              )
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()

# %%
#Interactive hystogram
import plotly.express as px
fig = px.bar(df, x='Sub-Category', y='Sales', text='Sales',
           	color ='Sub-Category')
fig.update_traces(texttemplate='%{text:.3s}', textposition='outside')
fig.update_layout({'plot_bgcolor': 'white',
                          	'paper_bgcolor': 'white'})
fig.update_layout(width=1100, height=500,
               margin = dict(t=15, l=15, r=15, b=15))
fig.show()

# %%
#Лепествкоая диаграмма:

import plotly.express as px
fig = px.line_polar(df, r='Sales',
                          	theta='Sub-Category', line_close=True)
fig.update_traces(fill='toself')
fig.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
#Pops:)

df['X'] = [1]*len(df)
list_y = list(range(0,len(df)))
list_y.reverse()
df['Y'] = list_y

# Столбец меток

df['labels'] = ['<b>'+i+'<br>'+format(j, ",") for i,j in zip(df['Sub-Category'], df['Sales'])]
df
# Out:
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 1160   1161  CA-2017-147039 2017-06-29    7/4/2017  Standard Class
# 6747   6748  CA-2017-100230 2017-12-11  12/15/2017  Standard Class
# 12       13  CA-2017-114412 2017-04-15   4/20/2017  Standard Class
# 7489   7490  CA-2017-157196 2017-11-05   11/9/2017  Standard Class
# 8801   8802  CA-2016-140935 2016-11-10  11/12/2016     First Class
# ...     ...             ...        ...         ...             ...
# 2845   2846  CA-2017-138163 2017-11-17  11/20/2017     First Class
# 5474   5475  CA-2017-121741 2017-12-26  12/26/2017        Same Day
# 1613   1614  CA-2017-138380 2017-12-21  12/25/2017  Standard Class
# 1229   1230  CA-2017-100013 2017-11-06  11/11/2017  Standard Class
# 8341   8342  CA-2017-141481 2017-06-11   6/14/2017     First Class
#
#      Customer ID       Customer Name    Segment        Country           City  \
# 1160    AA-10315          Alex Avila   Consumer  United States    Minneapolis
# ...

# %%
import plotly.express as px
fig = px.scatter(df, x='X', y='Y',
              color='Sub-Category',
              size='Sales', text='labels', size_max=30)
fig.update_layout(width=500, height=1100,
               margin = dict(t=0, l=0, r=0, b=0),
               showlegend=False
              )
fig.update_traces(textposition='middle right')
fig.update_xaxes(showgrid=False, zeroline=False, visible=False)
fig.update_yaxes(showgrid=False, zeroline=False, visible=False)
fig.update_layout({'plot_bgcolor': 'white',
                          	'paper_bgcolor': 'white'})
fig.show()
